# %% [markdown]
# <a href="https://colab.research.google.com/github/bye23mj/suanLee/blob/main/TF_3_2_%EC%BC%80%EB%9D%BC%EC%8A%A4_%EC%9E%90%EB%8F%99%EC%B0%A8_%EC%97%B0%EB%B9%84_%EC%98%88%EC%B8%A1_%EB%AA%A8%EB%8D%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 케라스 자동차 연비 예측 모델
#
# - Source : https://www.tensorflow.org/tutorials/keras/regression

# %% [markdown]
# ### modules import

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.models import Model
from tensorflow.keras.utils import get_file, plot_model

# %%
sns.set(style='white')
plt.style.use('seaborn-white')

# %% [markdown]
# ### 데이터 로드

# %%
dataget_path = get_file("auto-mpg.data", "http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data")
# Out:
# ...
# 40960/30286 [========================================] - 0s 4us/step

# %%
dataget_path
# Out:
# '/root/.keras/datasets/auto-mpg.data'

# %%
column_names = ['MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight', 'Acceleration', 'Model Year', 'Origin']

# %% [markdown]
# ### 데이터 확인

# %%
raw_dataset = pd.read_csv(dataget_path, names=column_names,
                          na_values='?', comment='\t',
                          sep=" ", skipinitialspace=True)
dataset = raw_dataset.copy()
dataset
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year  Origin
# 0            70       1
# 1            70       1
# 2            70       1
# 3            70       1
# ...

# %% [markdown]
# ### 데이터 전처리

# %% [markdown]
# - 해당 데이터는 일부 데이터가 누락되어 있음

# %%
dataset.isna().sum()
# Out:
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      6
# Weight          0
# Acceleration    0
# Model Year      0
# Origin          0
# dtype: int64

# %% [markdown]
# - 누락된 행 삭제

# %%
dataset = dataset.dropna()

# %% [markdown]
# - "Origin" 범주형 데이터
#   - 원-핫 인코딩(one-hot encoding) 진행

# %%
dataset["Origin"].unique()
# Out:
# array([1, 3, 2])

# %%
origin = dataset.pop('Origin')

# %%
dataset['USA'] = (origin==1) * 1.0
dataset['Europe'] = (origin==2) * 1.0
dataset['Japan'] = (origin==3) * 1.0
dataset
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# #### 검증 데이터셋 생성

# %%
train_dataset = dataset.sample(frac=0.8, random_state=0)
test_dataset = dataset.drop(train_dataset.index)

# %% [markdown]
# #### 데이터 조사

# %%
sns.pairplot(train_dataset[["MPG", "Cylinders", "Displacement", "Horsepower", "Weight"]], diag_kind='kde');

# %%
train_state = train_dataset.describe()
train_state.pop("MPG")
train_state = train_state.transpose()
train_state
# Out:
#               count         mean         std     min      25%     50%  \
# Cylinders     314.0     5.477707    1.699788     3.0     4.00     4.0
# Displacement  314.0   195.318471  104.331589    68.0   105.50   151.0
# Horsepower    314.0   104.869427   38.096214    46.0    76.25    94.5
# Weight        314.0  2990.251592  843.898596  1649.0  2256.50  2822.5
# Acceleration  314.0    15.559236    2.789230     8.0    13.80    15.5
# Model Year    314.0    75.898089    3.675642    70.0    73.00    76.0
# USA           314.0     0.624204    0.485101     0.0     0.00     1.0
# Europe        314.0     0.178344    0.383413     0.0     0.00     0.0
# Japan         314.0     0.197452    0.398712     0.0     0.00     0.0
#
#                   75%     max
# Cylinders        8.00     8.0
# Displacement   265.75   455.0
# Horsepower     128.00   225.0
# Weight        3608.00  5140.0
# Acceleration    17.20    24.8
# Model Year      79.00    82.0
# USA              1.00     1.0
# ...

# %% [markdown]
# #### 데이터의 특성과 레이블 분리

# %%
train_labels = train_dataset.pop('MPG')
test_labels = test_dataset.pop('MPG')

# %% [markdown]
# #### 데이터 정규화

# %%
def normalization(x):
  return (x - train_state['mean']) / train_state['std']

normed_train_data = normalization(train_dataset)
normed_test_data = normalization(test_dataset)

# %% [markdown]
# ### 모델 구성

# %%
def build_model():
  input = Input(shape=(len(train_dataset.keys())), name='input')
  hidden1 = Dense(64, activation='relu', name='dense1')(input)
  hidden2 = Dense(64, activation='relu', name='dense2')(hidden1)
  output = Dense(1, name='output')(hidden2)

  model = Model(inputs=[input], outputs=output)

  model.compile(loss='mse',
                optimizer=RMSprop(0.001),
                metrics=['mae', 'mse'])
  
  return model

# %%
model = build_model()

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input (InputLayer)          [(None, 9)]               0
#
#  dense1 (Dense)              (None, 64)                640
#
#  dense2 (Dense)              (None, 64)                4160
#
#  output (Dense)              (None, 1)                 65
#
# ...
# Total params: 4,865
# Trainable params: 4,865
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model)

# %% [markdown]
# ### 샘플 데이터 확인

# %%
sample_batch = normed_test_data[:10]
sample_result = model.predict(sample_batch)
sample_batch
# Out:
#     Cylinders  Displacement  Horsepower    Weight  Acceleration  Model Year  \
# 9    1.483887      1.865988    2.234620  1.018782     -2.530891   -1.604642
# 25   1.483887      1.578444    2.890853  1.925289     -0.559020   -1.604642
# 28   1.483887      1.041693    2.313368  2.063931      1.054328   -1.604642
# 31  -0.869348     -0.789008   -0.259066 -0.903250     -0.559020   -1.332580
# 33   0.307270      0.351586   -0.127819 -0.422150     -0.917542   -1.332580
# 39   1.483887      1.961837    1.840880  1.746357     -1.455325   -1.332580
# 40   1.483887      1.492180    1.263395  1.379015     -0.738281   -1.332580
# 43   1.483887      1.961837    1.709634  2.080521     -1.276064   -1.332580
# 48   0.307270      0.524113   -0.442811  0.176263     -0.379759   -1.332580
# 54  -0.869348     -1.181986   -0.941548 -1.632011      0.875068   -1.332580
#
#          USA    Europe     Japan
# 9   0.774676 -0.465148 -0.495225
# 25  0.774676 -0.465148 -0.495225
# ...

# %% [markdown]
# ### 모델 학습

# %%
epochs = 1000

history = model.fit(normed_train_data, train_labels,
                    epochs=epochs, validation_split=0.2)

# %% [markdown]
# ### 모델 학습 시각화

# %%
history.history.keys()

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure(figsize=(12,6))

  plt.subplot(1,2,1)
  plt.xlabel('Epochs')
  plt.ylabel('MPG Mean Absolute Error')
  plt.plot(hist['epoch'], hist['mae'], label='Train Error')
  plt.plot(hist['epoch'], hist['val_mae'], label='val Error')
  plt.ylim([0,5])
  plt.legend()

  plt.subplot(1,2,2)
  plt.xlabel('Epochs')
  plt.ylabel('MPG Mean Squerd Error')
  plt.plot(hist['epoch'], hist['mse'], label='Train Error')
  plt.plot(hist['epoch'], hist['val_mse'], label='val Error')
  plt.ylim([0,20])
  plt.legend()  

  plt.show()

plot_history(history)

# %% [markdown]
# ### EarlyStopping을 이용한 규제화

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
model = build_model()

early_stop = EarlyStopping(monitor='val_loss', patience=10)

history = model.fit(normed_train_data, train_labels, epochs=epochs,
                    validation_split=0.2, callbacks=[early_stop])

# %%
plot_history(history)

# %% [markdown]
# ### 모델 평가

# %%
loss, mae, mse = model.evaluate(normed_test_data, test_labels, verbose=2)
print(mae)
# Out:
# 3/3 - 0s - loss: 6.3192 - mae: 1.9358 - mse: 6.3192 - 45ms/epoch - 15ms/step
# 1.9357898235321045

# %% [markdown]
# ### 학습된 모델을 통한 예측

# %%
test_pred = model.predict(normed_test_data).flatten()

plt.scatter(test_labels, test_pred)
plt.xlabel('True valuse')
plt.ylabel('predictions')
plt.axis('equal')
plt.axis('square')
plt.grid()
plt.xlim([0, plt.xlim()[1]])
plt.xlim([0, plt.ylim()[1]])
plt.plot([-100, 100], [-100, 100])

# %%
error = test_pred - test_labels
plt.hist(error, bins=30)
plt.xlabel("Prediction Error")
plt.grid()
plt.ylabel("count")
# Out:
# Text(0, 0.5, 'count')
