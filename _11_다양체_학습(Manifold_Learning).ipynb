# %% [markdown]
# <a href="https://colab.research.google.com/github/bye23mj/suanLee/blob/main/_11_%EB%8B%A4%EC%96%91%EC%B2%B4_%ED%95%99%EC%8A%B5(Manifold_Learning).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 다양체 학습 (Manifold Learning)
#
# * 높은 차원의 데이터를 저차원으로 축소하는 방법
#
# ![manifold](https://scikit-learn.org/stable/_images/sphx_glr_plot_compare_methods_0011.png)
#
# * 고차원 데이터를 2차원 또는 3차원으로 축소해 시각화에 활용할 수 있음
# * 차원 축소 과정에서 중요하지 않은 정보는 버려지고 중요한 정보만 남기 때문에 데이터 정제에 활용 가능

# %% [markdown]
# ## 데이터 생성 및 시각화 함수

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use(['seaborn-whitegrid'])

from sklearn import manifold
from sklearn import random_projection
from sklearn import datasets

# %%
s_curve, color = datasets.make_s_curve(1000, random_state=0)

# %%
digits, labels = datasets.load_digits(return_X_y=True)
print(labels.shape)
rand_proj = random_projection.SparseRandomProjection(n_components=3, random_state=0)
projected_digits = rand_proj.fit_transform(digits)
# Out:
# (1797,)

# %%
def min_max_scale(x):
  min_value, max_value = np.min(x,0), np.max(x,0)
  x = (x - min_value) / (max_value - min_value)
  return x

# %%
def plot_s_curve(s_curve, color, position, projection):
  s_curve = min_max_scale(s_curve)
  if projection == '3d':
    ax = plt.subplot(position, projection = projection)
    ax.scatter(s_curve[:, 0], s_curve[:,1], s_curve[:,2], c=color, cmap=plt.cm.Spectral)
    ax.view_init(4, -72)
  elif projection == '2d':
    ax = plt.subplot(position)
    ax.scatter(s_curve[:, 0], s_curve[:,1], c=color, cmap=plt.cm.Spectral)

# %%
def plot_digits(digits, labels, position, projection):
  digits = min_max_scale(digits)
  if projection == '3d':
    ax = plt.subplot(position, projection = projection)
    for i in range(digits.shape[0]):
      ax.text(digits[i, 0], digits[i, 1],digits[i, 2], str(labels[i]), color=plt.cm.Set1(labels[i]/10.), fontdict={'weight':'bold','size':9})
      ax.view_init(4, -72)
  elif projection == '2d':
    ax = plt.subplot(position)
    for i in range(digits.shape[0]):
      ax.text(digits[i,0], digits[i,1], str(labels[i]), color=plt.cm.Set1(labels[i]/10.), fontdict={'weight':'bold','size':9})

# %%
fig = plt.figure(figsize=(20, 10))
plot_s_curve(s_curve, color, 121, '3d')
plot_digits(projected_digits, labels, 122, '3d')

# %% [markdown]
# ## Locally Linear Embedding (LLE)
#
# * 국소 이웃 거리를 보존하는 저차원 임베딩을 찾음

# %%
s_curve_lle = manifold.LocallyLinearEmbedding(n_neighbors=30, n_components=3, reg=0.001, method="standard", random_state=0).fit_transform(s_curve)
digit_lle = manifold.LocallyLinearEmbedding(n_neighbors=30, n_components=2, reg=0.001, method="standard", random_state=0).fit_transform(digits)

# %%
fig = plt.figure(figsize=(20,10))
plot_s_curve(s_curve_lle, color, 121, '3d')
plot_digits(digit_lle, labels, 122, '2d')

# %% [markdown]
# ## Local Tangent Space Alignment (LTSA)
#
# * 탄젠트 공간을 통해 각 이웃의 국소 성질을 특성화
# * 국소 탄젠트 공간을 정렬

# %%
s_curve_lle = manifold.LocallyLinearEmbedding(n_neighbors=30, n_components=3, reg=0.001, method="ltsa", random_state=0).fit_transform(s_curve)
digit_lle = manifold.LocallyLinearEmbedding(n_neighbors=30, n_components=2, reg=0.001, method="ltsa", random_state=0).fit_transform(digits)

# %%
fig = plt.figure(figsize=(20,10))
plot_s_curve(s_curve_lle, color, 121, '3d')
plot_digits(digit_lle, labels, 122, '2d')

# %% [markdown]
# ## Hessian Eigenmapping
#
# * LLE의 문제를 해결한 다른 방법
# * 국소 선형 구조를 복원하기 위해 각 이웃에서 hessian 기반의 이차 형태를 중심으로 회전

# %%
s_curve_lle = manifold.LocallyLinearEmbedding(n_neighbors=30, n_components=3, reg=0.001, method="hessian", random_state=0).fit_transform(s_curve)
digit_lle = manifold.LocallyLinearEmbedding(n_neighbors=30, n_components=3, reg=0.001, method="hessian", random_state=0).fit_transform(digits)

# %%
fig = plt.figure(figsize=(20,10))
plot_s_curve(s_curve_lle, color, 121, '3d')
plot_digits(digit_lle, labels, 122, '2d')

# %% [markdown]
# ## Modified Locally Linear Embedding
#
# * 각 이웃에 여러 가중치 벡터를 사용
# * n_neighbors > n_components를 만족해야 함

# %%
s_curve_lle = manifold.LocallyLinearEmbedding(n_neighbors=30, n_components=3, reg=0.001, method="modified", random_state=0).fit_transform(s_curve)
digit_lle = manifold.LocallyLinearEmbedding(n_neighbors=30, n_components=2, reg=0.001, method="modified", random_state=0).fit_transform(digits)

# %%
fig = plt.figure(figsize=(20,10))
plot_s_curve(s_curve_lle, color, 121, '3d')
plot_digits(digit_lle, labels, 122, '2d')

# %% [markdown]
# ## Isomap
#
# * 초기의 다양체 학습 알고리즘
# * MDS와 커널 PCA의 확장으로 볼 수 있음
# * 모든 점들 사이의 측지 거리를 유지하는 저차원 임베딩을 찾음

# %%
s_curve_lle = manifold.Isomap(n_neighbors=30, n_components=3).fit_transform(s_curve)
digit_lle = manifold.Isomap(n_neighbors=30, n_components=2).fit_transform(digits)

# %%
fig = plt.figure(figsize=(20,10))
plot_s_curve(s_curve_lle, color, 121, '3d')
plot_digits(digit_lle, labels, 122, '2d')

# %% [markdown]
# ## Multi-Dimensional Scaling (MDS)
#
# * 고차원 공간에서의 거리를 고려하는 저차원 공간을 찾음

# %%
s_curve_lle = manifold.MDS(n_components=3, random_state=0).fit_transform(s_curve)
digit_lle = manifold.MDS(n_components=2, random_state=0).fit_transform(digits)

# %%
fig = plt.figure(figsize=(20,10))
plot_s_curve(s_curve_lle, color, 121, '3d')
plot_digits(digit_lle, labels, 122, '2d')

# %% [markdown]
# ## Spectral Embedding
#
# * 스펙트럼 분해를 통해 데이터의 저차원 표현을 찾음
# * 데이터의 점이 저차원 공간에서도 서로 가깝게 유지되도록 함

# %%
s_curve_lle = manifold.SpectralEmbedding(n_components=3, random_state=0).fit_transform(s_curve)
digit_lle = manifold.SpectralEmbedding(n_components=2, random_state=0).fit_transform(digits)

# %%
fig = plt.figure(figsize=(20,10))
plot_s_curve(s_curve_lle, color, 121, '3d')
plot_digits(digit_lle, labels, 122, '2d')

# %% [markdown]
# ## t-distributed Stochastic Neighbor Embedding (t-SNE)
#
# * 데이터 포인트의 유사성을 확률로 변환
# * 국소 구조에 민감
# * 국소 구조를 기반으로 샘플 그룹을 추출하는데 강함
# * 항상 KL발산의 국소 최소값에서 끝남
# * 계산 비용이 많이 듬
# * 전역 구조를 보존하지 않음

# %%
s_curve_tsne = manifold.TSNE(n_components=3, random_state=0).fit_transform(s_curve)
digit_tsne = manifold.TSNE(n_components=3, random_state=0).fit_transform(digits)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,

# %%
fig = plt.figure(figsize=(20,10))
plot_s_curve(s_curve_tsne, color, 121, '3d')
plot_digits(digit_tsne, labels, 122, '2d')

# %% [markdown]
# ## 정제된 표현을 이용한 학습
# * 다양체 학습의 결과를 정제된 데이터로 생각할 수 있음
# * 정제된 표현이기 때문에 분석에 비교적 용이함
# * 기계학습 모델의 입력으로 사용했을때 성능향상을 기대할 수 있음

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# %%
raw_digits, target = datasets.load_digits(return_X_y=True)

# %%
knn = KNeighborsClassifier()
svm = SVC()
decisionTree = DecisionTreeClassifier()
random_forest = RandomForestClassifier()

# %% [markdown]
# ### 원본 데이터를 사용할 때

# %% [markdown]
# #### KNN

# %%
score = cross_val_score(estimator = knn, X=raw_digits, y=target, cv=5)

# %%
print('mean cross val score :{} (+/-{})'.format(score.mean(),score.std()))
# Out:
# mean cross val score :0.9627282575054161 (+/-0.011168537355954218)

# %% [markdown]
# #### SVM

# %%
score = cross_val_score(estimator = svm, X=raw_digits, y=target, cv=5)

# %%
print('mean cross val score :{} (+/-{})'.format(score.mean(),score.std()))
# Out:
# mean cross val score :0.9632838130609718 (+/-0.02008605863225686)

# %% [markdown]
# #### Decision Tree

# %%
score = cross_val_score(estimator = decisionTree, X=raw_digits, y=target, cv=5)

# %%
print('mean cross val score :{} (+/-{})'.format(score.mean(),score.std()))
# Out:
# mean cross val score :0.7835809346951408 (+/-0.04261354717915422)

# %% [markdown]
# #### Random Forest

# %%
score = cross_val_score(estimator = random_forest, X=raw_digits, y=target, cv=5)

# %%
print('mean cross val score :{} (+/-{})'.format(score.mean(),score.std()))
# Out:
# mean cross val score :0.9354673475704118 (+/-0.02071821039705356)

# %% [markdown]
# ### 정제된 데이터를 사용할 때

# %% [markdown]
# #### KNN

# %%
score = cross_val_score(estimator = knn, X=digit_tsne, y=target, cv=5)

# %%
print('mean cross val score :{} (+/-{})'.format(score.mean(),score.std()))
# Out:
# mean cross val score :0.973300835654596 (+/-0.011988329402734279)

# %% [markdown]
# #### SVM

# %%
score = cross_val_score(estimator = svm, X=digit_tsne, y=target, cv=5)

# %%
print('mean cross val score :{} (+/-{})'.format(score.mean(),score.std()))
# Out:
# mean cross val score :0.9627406375735067 (+/-0.02147317457111638)

# %% [markdown]
# #### Decision Tree

# %%
score = cross_val_score(estimator = decisionTree, X=digit_tsne, y=target, cv=5)

# %%
print('mean cross val score :{} (+/-{})'.format(score.mean(),score.std()))
# Out:
# mean cross val score :0.9349288146084804 (+/-0.03072699730048209)

# %% [markdown]
# #### Random Forest

# %%
score = cross_val_score(estimator = random_forest, X=digit_tsne, y=target, cv=5)

# %%
print('mean cross val score :{} (+/-{})'.format(score.mean(),score.std()))
# Out:
# mean cross val score :0.956641906530486 (+/-0.03601412982897665)
